# %% [markdown]
# ## Data
# - The data to be used for testing RSeQC have been obtained from RSeQC [test datasets](https://data.cyverse.org/dav-anon/iplant/home/liguow/RSeQC/). The filename is Pairend_StrandSpecific_51mer_Human_hg19.bam
# - The gene model is downloaded from RSeQC [example gene models](https://pythonhosted.org/RSeQC/#download-gene-models-update-on-08-07-2014). The filename is hg19.HouseKeepingGenes.bed
#
# ## Scripts
# - As included in the stat115 lectures, I will test the genebodycoverage.py and tin.py files.

# %% [markdown]
# ## Gene Body Coverage
# - The example usage of the file is given in the RSeQC [documentation](https://pythonhosted.org/RSeQC/#genebody-coverage-py)

# %%
# !python filepath/geneBody_coverage.py -i ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam -r ../data/hg19.HouseKeepingGenes.bed -o output
# Out:
# @ 2024-04-03 19:03:06: Read BED file (reference gene model) ...
# @ 2024-04-03 19:03:06: Total 4040 transcripts loaded
# @ 2024-04-03 19:03:06: Get BAM file(s) ...
# 	../data/Pairend_StrandSpecific_51mer_Human_hg19.bam
# @ 2024-04-03 19:03:06: Processing Pairend_StrandSpecific_51mer_Human_hg19.bam ...
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# ...

# %%
# !python filepath/geneBody_coverage.py --version
# Out:
# geneBody_coverage.py 5.0.2

# %%
# !python filepath/geneBody_coverage.py -h
# Out:
# Usage: geneBody_coverage.py [options]
#
# Calculate the RNA-seq reads coverage over gene body.
#
# Note:
# 1) Only input sorted and indexed BAM file(s). SAM format is not supported.
# 2) Genes/transcripts with mRNA length < 100 will be skipped (Number specified to "-l" cannot be < 100).
#
#
#
# Options:
#   --version             show program's version number and exit
#   -h, --help            show this help message and exit
#   -i INPUT_FILES, --input=INPUT_FILES
#                         Input file(s) in BAM format. "-i" takes these input:
#                         1) a single BAM file. 2) "," separated BAM files. 3)
#                         directory containing one or more bam files. 4) plain
#                         text file containing the path of one or more bam file
#                         (Each row is a BAM file path). All BAM files should be
#                         sorted and indexed using samtools.
#   -r REF_GENE_MODEL, --refgene=REF_GENE_MODEL
# ...

# %% [markdown]
# ## transcript integrity number

# %%
# !python filepath/tin.py -h
# Out:
# Usage: tin.py [options]
# -------------------------------------------------------------------------------------------------
# This program calculates transcript integrity number (TIN) for each transcript (or gene) in
# BED file. TIN is conceptually similar to RIN (RNA integrity number) but provides transcript
# level measurement of RNA quality and is more sensitive to measure low quality RNA samples:
#
# 1) TIN score of a transcript is used to measure the RNA integrity of the transcript.
# 2) Median TIN score across all transcripts can be used to measure RNA integrity  of that
#    "RNA sample".
# 3) TIN ranges from 0 (the worst) to 100 (the best). TIN = 60 means: 60% of the transcript
#    has been covered if the reads coverage were uniform.
# 4) TIN will be assigned to 0 if the transcript has no coverage or covered reads is fewer than
#    cutoff.
# -------------------------------------------------------------------------------------------------
#
#
# Options:
# ...

# %%
# !python filepath/tin.py -i ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam -r ../data/hg19.HouseKeepingGenes.bed
# Out:
# @ 2024-04-03 19:13:04: Get BAM file(s) ...
# Total 1 BAM file(s):
# 	../data/Pairend_StrandSpecific_51mer_Human_hg19.bam
# @ 2024-04-03 19:13:04: Processing ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# [W::hts_idx_load3] The index file is older than the data file: ../data/Pairend_StrandSpecific_51mer_Human_hg19.bam.bai
# ...
